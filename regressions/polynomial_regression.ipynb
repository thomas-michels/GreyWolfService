# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
with open("../data/properties.pkl", "rb") as file:
    x_properties_train, y_properties_train, x_properties_test, y_properties_test = pickle.load(file)

# %%
x_properties_train.shape, x_properties_test.shape
# Out:
# ((3614, 60), (1205, 60))

# %% [markdown]
# Treinamento das features

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)

x_properties_train_poly = poly.fit_transform(x_properties_train)
x_properties_test_poly = poly.transform(x_properties_test)

# %%
x_properties_train_poly.shape, x_properties_test_poly.shape
# Out:
# ((3614, 1891), (1205, 1891))

# %% [markdown]
# Aplicando a regressao

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
regressor_properties_poly = LinearRegression()
regressor_properties_poly.fit(x_properties_train_poly, y_properties_train)
# Out:
# LinearRegression()

# %%
regressor_properties_poly.score(x_properties_train_poly, y_properties_train)
# Out:
# 0.6713600303165458

# %%
regressor_properties_poly.score(x_properties_test_poly, y_properties_test)
# Out:
# -3.2577352321027995e+21

# %% [markdown]
# Previsoes

# %%
predictions = regressor_properties_poly.predict(x_properties_test_poly)
predictions
# Out:
# array([297648., 410856., 567736., ..., 611328., 529780., 647600.])

# %%
y_properties_test
# Out:
# id
# 1629    255000.0
# 3768    370000.0
# 5584    489000.0
# 35      125000.0
# 1806    800000.0
#           ...
# 8999    890000.0
# 4866    440000.0
# 7923    720000.0
# 6944    607126.0
# 7152    639020.0
# Name: price, Length: 1205, dtype: float64

# %% [markdown]
# Metricas

# %%
mean_absolute_error(y_properties_test, predictions)
# Out:
# 1811953946023933.0

# %%
mean_squared_error(y_properties_test, predictions)
# Out:
# 2.5471187750549403e+32

# %%
grafico = px.scatter(x=y_properties_test, y=predictions)
grafico
