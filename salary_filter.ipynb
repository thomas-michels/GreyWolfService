# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("./data/salaries.csv", sep=";")
df
# Out:
#         neighborhood  no_salary  one_salary  between_one_and_three  \
# 0         Água Verde       3.85        1.79                  20.45
# 1          Badenfurt       0.73        2.84                  29.13
# 2          Boa Vista       1.02        2.72                  19.18
# 3         Bom Retiro       0.74        2.22                  18.19
# 4             Centro       1.36        4.13                  26.39
# 5          Da Glória       1.91        3.82                  28.96
# 6           Do Salto       0.83        3.39                  25.47
# 7    Escola Agrícola       1.61        3.07                  22.96
# 8            Fidélis       0.44        3.13                  30.30
# 9          Fortaleza       3.58        2.54                  23.67
# 10    Fortaleza Alta       0.64        1.86                  24.54
# 11            Garcia       1.74        2.96                  24.16
# 12  Itoupava Central       1.08        2.61                  25.73
# 13    Itoupava Norte       1.18        2.50                  24.69
# 14     Itoupava Seca       2.48        1.24                  15.90
# 15     Itoupavazinha       0.67        2.50                  27.03
# 16   Jardim Blumenau       1.20        0.40                   4.29
# 17    Nova Esperança       0.56        4.43                  32.74
# 18       Passo Manso       3.96        2.27                  21.89
# 19        Ponta Agua       1.67        2.72                  24.06
# 20          Pogresso       0.68        3.21                  26.32
# 21   Ribeirão Fresco       2.53        3.50                  24.57
# 22    Salto do Norte       1.37        2.16                  25.04
# 23   Salto Weissbach       1.03        1.61                  16.71
# 24       Testo Salto       0.61        1.97                  24.78
# 25           Tribess       1.45        2.08                  22.71
# 26        Valparaíso       0.45        2.93                  25.14
# 27             Velha       1.61        1.94                  18.87
# 28     Velha Central       2.14        2.20                  22.49
# 29      Velha Grande       2.62        3.85                  37.68
# 30     Victor Konder       6.18        1.31                  13.11
# 31      Vila Formosa       1.24        2.48                  13.63
# 32     Vila Itoupava       0.46        2.30                  24.66
# 33         Vila Nova       2.52        2.08                  14.26
# 34          Vorstadt       3.37        2.78                  17.51
#
#     between_three_and_five  between_five_ten  more_than_ten
# 0                    25.43             34.00          14.48
# 1                    31.49             29.42           6.40
# 2                    30.56             34.80          11.72
# 3                    17.94             29.98          30.96
# 4                    25.52             24.97          17.64
# 5                    32.40             28.01           4.91
# 6                    28.79             27.13          14.39
# 7                    25.86             30.03          16.47
# 8                    35.82             25.99           4.32
# 9                    28.80             31.89           9.52
# 10                   33.40             31.76           7.79
# 11                   25.62             30.40          15.12
# 12                   34.02             30.50           6.06
# 13                   27.31             31.19          13.14
# 14                   20.54             33.48          26.36
# 15                   36.56             28.69           4.57
# 16                    7.37             20.62          66.15
# 17                   31.45             25.48           5.32
# 18                   33.64             32.33           5.88
# 19                   25.18             26.07          20.29
# 20                   34.54             29.80           5.44
# 21                   24.76             28.46          16.17
# 22                   29.97             32.57           8.90
# 23                   29.56             38.37          12.72
# 24                   36.11             30.73           5.81
# 25                   32.74             32.48           8.54
# 26                   31.34             33.20           6.93
# 27                   23.91             31.79          21.88
# 28                   30.12             32.88          10.18
# 29                   34.32             19.25           2.29
# 30                   16.73             27.44          35.22
# 31                   19.42             31.40          31.82
# 32                   31.11             33.18           8.29
# 33                   18.59             31.00          31.54
# 34                   21.48             31.18          23.66

# %%
df.describe()
# Out:
#        no_salary  one_salary  between_one_and_three  between_three_and_five  \
# count  35.000000   35.000000              35.000000               35.000000
# mean    1.700286    2.558286              22.777429               27.782857
# std     1.266430    0.840009               6.201638                6.545384
# min     0.440000    0.400000               4.290000                7.370000
# 25%     0.735000    2.080000              19.025000               24.970000
# 50%     1.360000    2.500000              24.160000               29.560000
# 75%     2.310000    3.015000              25.600000               32.570000
# max     6.180000    4.430000              37.680000               36.560000
#
#        between_five_ten  more_than_ten
# count         35.000000      35.000000
# mean          30.013429      15.168000
# std            3.790997      12.640356
# min           19.250000       2.290000
# 25%           28.235000       6.230000
# 50%           30.730000      11.720000
# 75%           32.405000      18.965000
# max           38.370000      66.150000

# %% [markdown]
# ### Agrupando bairros com base na renda

# %%
from typing import List


def get_range(brute_salary: float) -> List[str]:

    if brute_salary < 0:
        return ["no_salary"]

    minimum_salary = 1302

    proximities = {}
    categories = {"no_salary": 0, "one_salary": 1, "between_one_and_three": 3, "between_three_and_five": 5, "between_five_ten": 10, "more_than_ten": 20}

    for category, value in categories.items():
        max_of_range = value * minimum_salary

        if category == "more_than_ten" and brute_salary > max_of_range:
            proximity = 100

        elif brute_salary == 0:
            proximity = 0

        elif max_of_range < brute_salary:
            proximity = (max_of_range / brute_salary) * 100
        
        else:
            proximity = (brute_salary / max_of_range) * 100

        proximities[category] = round(proximity, 2)


    return proximities

# %%
get_range(5000)
# Out:
# {'no_salary': 0.0,
#  'one_salary': 26.04,
#  'between_one_and_three': 78.12,
#  'between_three_and_five': 76.8,
#  'between_five_ten': 38.4,
#  'more_than_ten': 19.2}

# %% [markdown]
# Busca bairros com base nas 2 categorias com mais similiaridade

# %%
def get_neighbors_by_salary_similarity(salary: float, top: int=5):
    ranges = get_range(salary)

    best_fits = [(None, 0), (None, 0)]

    for category, proximity in ranges.items():
        for fit in best_fits:
            if fit[1] < proximity and category != best_fits[0][0] and category != best_fits[1][0]:
                best_fits.insert(0, (category, proximity))

            if len(best_fits) > 2:
                best_fits.pop()

    return df.sort_values(by=[best_fits[0][0], best_fits[1][0]], ascending=False).iloc[:top, :]

# %%
get_neighbors_by_salary_similarity(3000, 5)
# Out:
#      neighborhood  no_salary  one_salary  between_one_and_three  \
# 15  Itoupavazinha       0.67        2.50                  27.03
# 24    Testo Salto       0.61        1.97                  24.78
# 8         Fidélis       0.44        3.13                  30.30
# 20       Pogresso       0.68        3.21                  26.32
# 29   Velha Grande       2.62        3.85                  37.68
#
#     between_three_and_five  between_five_ten  more_than_ten
# 15                   36.56             28.69           4.57
# 24                   36.11             30.73           5.81
# 8                    35.82             25.99           4.32
# 20                   34.54             29.80           5.44
# 29                   34.32             19.25           2.29
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
